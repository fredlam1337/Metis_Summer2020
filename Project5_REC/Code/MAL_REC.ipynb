# %%
import pandas as pd
import numpy as np
import pickle

from surprise import Dataset, Reader, SVD, SVDpp, accuracy
from surprise.model_selection import GridSearchCV, cross_validate

import seaborn as sns
import matplotlib.pyplot as plt

from collections import defaultdict, Counter

import warnings
warnings.filterwarnings("ignore")

# %%
score_df = pd.read_csv('rate_df.csv') #user/scores
det_df = pd.read_csv('det_df.csv') #anime/rating/genres

# %%
det_df = det_df[det_df['Rating'] != 'None']

# %%
# test_csv = pd.read_csv('test_csv.csv')
# test_csv['Score'] = test_csv['Score'].map(int)

# %%
# df_list = [score_df, test_csv]
# score_df = pd.concat(df_list)

# %%
# score_df.to_pickle('score_df.pkl')
# det_df.to_pickle('det_df.pkl')

# %% [markdown]
# ### Cleaning

# %%
# creates AnimeID for each anime
# score_df
grouped_name = score_df.groupby('Anime')

temp_df = grouped_name.count()
temp_df_idx = pd.DataFrame(temp_df.index)

temp_df_idx['AnimeID'] = temp_df_idx.index
dict_df=temp_df_idx[['AnimeID','Anime']]

desc_dict = dict_df.set_index('Anime').to_dict()
new_dict = desc_dict['AnimeID']

score_df['AnimeID'] = score_df['Anime'].map(new_dict)

# det_df
grouped_name = det_df.groupby('Anime')

temp_df = grouped_name.count()
temp_df_idx = pd.DataFrame(temp_df.index)

temp_df_idx['AnimeID'] = temp_df_idx.index
dict_df=temp_df_idx[['AnimeID','Anime']]

desc_dict = dict_df.set_index('Anime').to_dict()
new_dict = desc_dict['AnimeID']

det_df['AnimeID'] = det_df['Anime'].map(new_dict)

# create UserID for each user
grouped_user = score_df.groupby('User')

temp_df_user = grouped_user.count()
temp_df_user_idx = pd.DataFrame(temp_df_user.index)

temp_df_user_idx['UserID']=temp_df_user_idx.index
dict_df_user=temp_df_user_idx[['UserID','User']] 

desc_dict_user = dict_df_user.set_index('User').to_dict()
new_dict_user = desc_dict_user['UserID']

score_df['UserID'] = score_df['User'].map(new_dict_user)

# %%
# remove shows/users with low counts
min_anime_ratings = 2
min_user_ratings =  2

clean_ani_ratings = score_df.groupby('AnimeID').filter(lambda x: x['AnimeID'].count() >= min_anime_ratings)
test_df = clean_ani_ratings.groupby('UserID').filter(lambda x: x['UserID'].count() >= min_user_ratings)

"{0} shows deleted. Old dimensions: {1}; New dimensions: {2}"\
.format(len(score_df['AnimeID'].value_counts()) - len(test_df['AnimeID'].value_counts())\
        ,score_df.shape, test_df.shape )
# Out:
# '4 shows deleted. Old dimensions: (4401, 5); New dimensions: (2006, 5)'

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2006 entries, 1 to 4399
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Anime    2006 non-null   object
#  1   User     2006 non-null   object
#  2   Score    2006 non-null   int64
#  3   AnimeID  2006 non-null   int64
#  4   UserID   2006 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 94.0+ KB

# %% [markdown]
# ### Model

# %%
reader = Reader(rating_scale=(test_df['Score'].min(), test_df['Score'].max()))
data = Dataset.load_from_df(test_df[["UserID", "AnimeID", "Score"]], reader=reader)

trainset = data.build_full_trainset()
testset = trainset.build_anti_testset()

# %%
# return best param from list of searched parameters
t_list = []
for i in range(1,101,1):
    t_list.append(i)

n_list = []    
    
for i in range(0,11):
    param_grid = {'n_factors': t_list}
    gs = GridSearchCV(SVD, param_grid, measures=['rmse'], cv=5)
    gs.fit(data)

    n_list.append(gs.best_params['rmse'])

t2 = []

for sub in n_list:
    for key in sub:
        t2.append(int(sub[key]))

t2 = list(set(sorted(t2)))
print(t2, '\n')

param_grid = {'n_factors': t2}
gs = GridSearchCV(SVD, param_grid, measures=['rmse'], cv=5)
gs.fit(data)

print(gs.best_params['rmse'])

# %%
algo_SVD = SVD(n_factors = 5, random_state=4444)
algo_SVD.fit(trainset)

testset = trainset.build_anti_testset()

predictions = algo_SVD.test(testset)

predictions[0:10]
# Out:
# [Prediction(uid=155, iid=84, r_ui=7.9411764705882355, est=8.348596735891386, details={'was_impossible': False}),
#  Prediction(uid=155, iid=58, r_ui=7.9411764705882355, est=8.999081057674939, details={'was_impossible': False}),
#  Prediction(uid=155, iid=46, r_ui=7.9411764705882355, est=8.13063806626297, details={'was_impossible': False}),
#  Prediction(uid=155, iid=50, r_ui=7.9411764705882355, est=8.633872457895134, details={'was_impossible': False}),
#  Prediction(uid=155, iid=205, r_ui=7.9411764705882355, est=8.76882539737906, details={'was_impossible': False}),
#  Prediction(uid=155, iid=51, r_ui=7.9411764705882355, est=8.655350418150467, details={'was_impossible': False}),
#  Prediction(uid=155, iid=1, r_ui=7.9411764705882355, est=8.523988247615378, details={'was_impossible': False}),
#  Prediction(uid=155, iid=104, r_ui=7.9411764705882355, est=7.161381855954086, details={'was_impossible': False}),
#  Prediction(uid=155, iid=113, r_ui=7.9411764705882355, est=7.484476979266376, details={'was_impossible': False}),
#  Prediction(uid=155, iid=52, r_ui=7.9411764705882355, est=8.384846207983971, details={'was_impossible': False})]

# %%
# accuracy metric, lower is better!
accuracy.rmse(predictions)
# Out:
# RMSE: 0.6517
# 0.651661527711851

# %%
# borrowed from https://www.jiristodulka.com/post/recsys_cf/ 
def get_top_n(predictions, userId, anime_df, ratings_df, n = 10):
    # map the predictions to each user
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # sort the predictions for each user and retrieve the k highest ones
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key = lambda x: x[1], reverse = True)
        top_n[uid] = user_ratings[: n ]
    
    # returns how many movies the user has already rated
    user_data = ratings_df[ratings_df['UserID'] == (userId)]
    print('User {0} has already rated {1} shows/movies.'.format(userId, user_data.shape[0]))

    # DataFrame with predictions
    preds_df = pd.DataFrame([(id, pair[0],pair[1]) for id, row in top_n.items() for pair in row],
                        columns=['UserID' , 'AnimeID', 'PredScore'])
    
    # return top N recommended anime with (merged) titles and genres 
    pred_usr = preds_df[preds_df['UserID'] == (userId)].merge(anime_df, how = 'left', left_on = 'AnimeID', right_on = 'AnimeID')
            
    # return top N historically rated anime with (merged) titles and genres for holistic evaluation
    hist_usr = ratings_df[ratings_df['UserID'] == (userId) ].sort_values('Score', ascending = False).merge\
    (anime_df, how = 'left', left_on = 'AnimeID', right_on = 'AnimeID')
    
    return hist_usr, pred_usr

# %%
hist_SVD_837, pred_SVD_837 = get_top_n(predictions, anime_df = det_df, userId = 349, ratings_df = test_df)
# Out:
# User 349 has already rated 23 shows/movies.

# %%
hist_SVD_837
# Out:
#                                               Anime_x           User  Score  \
# 0                       Shouwa Genroku Rakugo Shinjuu  CodeBlazeFate     10
# 1      Neon Genesis Evangelion: The End of Evangelion  CodeBlazeFate     10
# 2                      Mobile Suit Gundam: The Origin  CodeBlazeFate     10
# 3                                        Sennen Joyuu  CodeBlazeFate     10
# 4   Shouwa Genroku Rakugo Shinjuu: Sukeroku Futata...  CodeBlazeFate     10
# 5                                    Tokyo Godfathers  CodeBlazeFate      9
# 6                             Ping Pong the Animation  CodeBlazeFate      9
# 7                                Kenpuu Denki Berserk  CodeBlazeFate      9
# 8   Kaguya-sama wa Kokurasetai: Tensai-tachi no Re...  CodeBlazeFate      9
# 9                                             Redline  CodeBlazeFate      9
# 10  Fate/stay night Movie: Heaven's Feel - II. Los...  CodeBlazeFate      8
# 11                      Suzumiya Haruhi no Shoushitsu  CodeBlazeFate      8
# 12                               Fate/Zero 2nd Season  CodeBlazeFate      8
# 13                                       Vinland Saga  CodeBlazeFate      8
# 14                               Houseki no Kuni (TV)  CodeBlazeFate      7
# 15                                              Given  CodeBlazeFate      7
# 16                                          Fate/Zero  CodeBlazeFate      7
# 17  Fate/stay night Movie: Heaven's Feel - I. Pres...  CodeBlazeFate      7
# 18                                  Violet Evergarden  CodeBlazeFate      6
# 19                                  Mob Psycho 100 II  CodeBlazeFate      6
# 20                                        Tenki no Ko  CodeBlazeFate      5
# 21           Kono Subarashii Sekai ni Shukufuku wo! 2  CodeBlazeFate      4
# 22  Fate/stay night: Unlimited Blade Works 2nd Season  CodeBlazeFate      4
#
#     AnimeID  UserID                                            Anime_y  \
# 0       211     349  Shouwa Genroku Rakugo Shinjuu: Sukeroku Futata...
# 1       165     349                                           Nichijou
# 2       142     349                   Monogatari Series: Second Season
# 3       199     349                                            Shelter
# 4       212     349                                          Slam Dunk
# 5       227     349                                   Tonari no Totoro
# 6       179     349                                           Planetes
# 7       102     349                                   Kimetsu no Yaiba
# 8        92     349  Kaguya-sama wa Kokurasetai?: Tensai-tachi no R...
# 9       186     349                                  Romeo no Aoi Sora
# 10       40     349  Fate/stay night Movie: Heaven's Feel - II. Los...
# 11      222     349                         Tengen Toppa Gurren Lagann
# 12       38     349                               Fate/Zero 2nd Season
# 13      235     349                                  Violet Evergarden
# 14       81     349                                Howl no Ugoku Shiro
# 15       61     349                                              Given
# 16       37     349                                          Fate/Zero
# 17       39     349  Fate/stay night Movie: Heaven's Feel - I. Pres...
# 18      236     349  Violet Evergarden Gaiden: Eien to Jidou Shuki ...
# 19      141     349                     Mobile Suit Gundam: The Origin
# 20      225     349                             Tenkuu no Shiro Laputa
# 21      116     349  Kono Subarashii Sekai ni Shukufuku wo!: Kurena...
# 22       42     349  Fate/stay night: Unlimited Blade Works 2nd Season
#
#                             Rating  \
# 0        PG-13 - Teens 13 or older
# 1        PG-13 - Teens 13 or older
# 2   R - 17+ (violence & profanity)
# 3                     G - All Ages
# 4        PG-13 - Teens 13 or older
# 5                     G - All Ages
# 6        PG-13 - Teens 13 or older
# 7   R - 17+ (violence & profanity)
# 8        PG-13 - Teens 13 or older
# 9        PG-13 - Teens 13 or older
# 10  R - 17+ (violence & profanity)
# 11       PG-13 - Teens 13 or older
# 12  R - 17+ (violence & profanity)
# 13       PG-13 - Teens 13 or older
# 14                    G - All Ages
# 15       PG-13 - Teens 13 or older
# 16  R - 17+ (violence & profanity)
# 17  R - 17+ (violence & profanity)
# 18       PG-13 - Teens 13 or older
# 19                R+ - Mild Nudity
# 20                   PG - Children
# 21       PG-13 - Teens 13 or older
# 22  R - 17+ (violence & profanity)
#
#                                                Genres
# 0                    ['Drama', 'Historical', 'Josei']
# 1    ['Slice of Life', 'Comedy', 'School', 'Shounen']
# 2   ['Mystery', 'Comedy', 'Supernatural', 'Romance...
# 3                                 ['Sci-Fi', 'Music']
# 4   ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 5             ['Adventure', 'Comedy', 'Supernatural']
# 6   ['Drama', 'Romance', 'Sci-Fi', 'Seinen', 'Space']
# 7   ['Action', 'Demons', 'Historical', 'Shounen', ...
# 8   ['Comedy', 'Psychological', 'Romance', 'School...
# 9   ['Adventure', 'Drama', 'Historical', 'Slice of...
# 10     ['Action', 'Fantasy', 'Magic', 'Supernatural']
# 11  ['Action', 'Adventure', 'Comedy', 'Mecha', 'Sc...
# 12     ['Action', 'Supernatural', 'Magic', 'Fantasy']
# 13              ['Slice of Life', 'Drama', 'Fantasy']
# 14       ['Adventure', 'Drama', 'Fantasy', 'Romance']
# 15  ['Drama', 'Music', 'Romance', 'Shounen Ai', 'S...
# 16     ['Action', 'Supernatural', 'Magic', 'Fantasy']
# 17     ['Action', 'Fantasy', 'Magic', 'Supernatural']
# 18              ['Drama', 'Fantasy', 'Slice of Life']
# 19  ['Action', 'Mecha', 'Military', 'Sci-Fi', 'Sho...
# 20      ['Adventure', 'Fantasy', 'Romance', 'Sci-Fi']
# 21  ['Adventure', 'Comedy', 'Fantasy', 'Magic', 'P...
# 22     ['Action', 'Fantasy', 'Magic', 'Supernatural']

# %%
pred_SVD_837
# Out:
#    UserID  AnimeID  PredScore  \
# 0     349      189   8.763629
# 1     349      145   8.682854
# 2     349        4   8.589087
# 3     349      129   8.581745
# 4     349      108   8.480882
# 5     349        6   8.465558
# 6     349       58   8.460181
# 7     349       74   8.422486
# 8     349       69   8.403109
# 9     349       41   8.390011
#
#                                                Anime  \
# 0                                         SKET Dance
# 1                                            Monster
# 2                               Aria the Origination
# 3  Mahou Shoujo Madoka★Magica Movie 3: Hangyaku n...
# 4                         Kiseijuu: Sei no Kakuritsu
# 5                                    Ashita no Joe 2
# 6                                           Gintama°
# 7                             Hajime no Ippo: Rising
# 8  Haikyuu!!: Karasuno Koukou vs. Shiratorizawa G...
# 9  Fate/stay night Movie: Heaven's Feel - III. Sp...
#
#                            Rating  \
# 0       PG-13 - Teens 13 or older
# 1                R+ - Mild Nudity
# 2                    G - All Ages
# 3       PG-13 - Teens 13 or older
# 4  R - 17+ (violence & profanity)
# 5       PG-13 - Teens 13 or older
# 6       PG-13 - Teens 13 or older
# 7       PG-13 - Teens 13 or older
# 8       PG-13 - Teens 13 or older
# 9  R - 17+ (violence & profanity)
#
#                                               Genres
# 0                    ['Comedy', 'School', 'Shounen']
# 1  ['Drama', 'Horror', 'Mystery', 'Police', 'Psyc...
# 2  ['Sci-Fi', 'Slice of Life', 'Fantasy', 'Shounen']
# 3  ['Mystery', 'Psychological', 'Drama', 'Magic',...
# 4  ['Action', 'Sci-Fi', 'Horror', 'Psychological'...
# 5  ['Action', 'Drama', 'Shounen', 'Slice of Life'...
# 6  ['Action', 'Comedy', 'Historical', 'Parody', '...
# 7           ['Comedy', 'Sports', 'Drama', 'Shounen']
# 8  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 9     ['Action', 'Supernatural', 'Magic', 'Fantasy']

# %% [markdown]
# ### User UI

# %%
from ast import literal_eval

g = []

for gn in det_df['Genres']:
    g.append(literal_eval(gn))

for g_list in g:
    tg += g_list

# sorted(list(set(tg)))

# %%
r = []

for rating in det_df['Rating']:
    r.append(rating)

sorted(list(set(r)))
# Out:
# ['G - All Ages',
#  'PG - Children',
#  'PG-13 - Teens 13 or older',
#  'R - 17+ (violence & profanity)',
#  'R+ - Mild Nudity']

# %%
test_rt = ['G - All Ages', 'R+ - Mild Nudity']
test_in = []

for index, rating in enumerate(pred_SVD_837['Rating']):
    if rating in test_rt:
        print(rating)
        print(index)
        test_in.append(index)
# Out:
# R+ - Mild Nudity
# 1
# G - All Ages
# 6

# %%
test_li = ['Action', 'Adventure']
test_in2 = []

for index, gn in enumerate(pred_SVD_837['Genres']):
    #for gt in test_li:
    if all(x in literal_eval(gn) for x in test_li):
        #if gt in literal_eval(gn):
        print(gn)
        print(index)
        test_in2.append(index)
            
for num in test_in2:
    print(pred_SVD_837.iloc[num].Anime)
# Out:
# ['Action', 'Adventure', 'Demons', 'Drama', 'Fantasy', 'Horror', 'Military', 'Romance', 'Seinen', 'Supernatural']
# 1
# ['Action', 'Adventure', 'Fantasy']
# 2
# Kenpuu Denki Berserk
# Mononoke Hime

# %%
def intersection(lst1, lst2): 
    lst3 = [value for value in lst1 if value in lst2] 
    return lst3

final_list = intersection(test_in, test_in2)

for num in final_list:
    print(pred_SVD_837.iloc[num].Anime)
# Out:
# Kenpuu Denki Berserk
